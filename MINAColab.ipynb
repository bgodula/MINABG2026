# %% [markdown]
# <a href="https://colab.research.google.com/github/bgodula/MINABG2026/blob/main/MINAColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# New colab file in Google Drive

# %%
from PIL import Image
img = Image.open("/content/drive/Shareddrives/MINABG2026/Grosser_Panda.JPG")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x167>
